# %%
import numpy as np
import pywt  #python wavelet transform
import cv2

# %%
from matplotlib import pyplot as plt
img = cv2.imread('./data/chris_evans/chris_evans1.png')
plt.imshow(img)

# %%
def w2d(img, mode='haar',level=1):
    
    img_array = img 
    img_array = cv2.cvtColor(img_array,cv2.COLOR_RGB2BGR)
    img_array = np.float32(img_array)
    img_array/= 255

    coffs = pywt.wavedec2(img_array, mode, level)
    coffs_h = list(coffs)
    coffs_h[0] *= 
    
    img_array_h = pywt.wavedec2(coffs_h, mode)
    img_array_h*= 255
    img_array_h = np.uint8(img_array_h)

    return img_array_h

# %%
w2d(img)
# Out:
# [array([[[0.19215685, 0.1372549 ],
#          [0.2352941 , 0.18039216],
#          [0.3       , 0.23529413],
#          ...,
#          [0.03921569, 0.05490196],
#          [0.7980392 , 0.84313726],
#          [0.8392157 , 0.88627446]],
#
#         [[0.20784312, 0.14117648],
#          [0.27058822, 0.19607843],
#          [0.27058822, 0.19607843],
#          ...,
#          [0.05098039, 0.0509804 ],
#          [0.66078424, 0.6823529 ],
#          [0.88627446, 0.90980387]],
#
#         [[0.15294117, 0.0862745 ],
#          [0.21960784, 0.15294117],
#          [0.25882354, 0.18823528],
#          ...,
#          [0.01568627, 0.01568627],
#          [0.6607843 , 0.6705882 ],
#          [0.86274505, 0.88627446]],
#
#         ...,
#
#         [[0.8784313 , 0.92549014],
#          [0.87450975, 0.92156863],
#          [0.87450975, 0.92156863],
#          ...,
#          [0.8549019 , 0.8666666 ],
#          [0.85098034, 0.86274505],
#          [0.84313726, 0.85490197]],
#
#         [[0.8862745 , 0.93333334],
#          [0.8901961 , 0.93725485],
#          [0.8941176 , 0.9411765 ],
#          ...,
#          [0.85098034, 0.86274505],
#          [0.8470588 , 0.8588235 ],
#          [0.84313726, 0.85490197]],
#
#         [[0.8862745 , 0.93333334],
#          [0.8901961 , 0.93725485],
#          [0.8941176 , 0.9411765 ],
#          ...,
#          [0.8549019 , 0.8666666 ],
#          [0.85098034, 0.86274505],
#          [0.84313726, 0.85490197]]], dtype=float32),
#  (array([[[ 0.05882353,  0.05882353],
#           [ 0.03921568,  0.03921568],
#           [-0.03333334, -0.02352942],
#           ...,
#           [ 0.03529412,  0.03921568],
#           [-0.1117647 , -0.11372551],
#           [ 0.        ,  0.        ]],
#
#          [[-0.03921568, -0.03921569],
#           [ 0.0862745 ,  0.08627451],
#           [-0.03921568, -0.03921568],
#           ...,
#           [-0.01960784, -0.01960784],
#           [-0.17058824, -0.17254901],
#           [ 0.        ,  0.        ]],
#
#          [[-0.03137255, -0.03137255],
#           [ 0.05098039,  0.05098039],
#           [-0.02745099, -0.02352942],
#           ...,
#           [-0.00784314, -0.00784314],
#           [-0.19019607, -0.2       ],
#           [ 0.        ,  0.        ]],
#
#          ...,
#
#          [[ 0.        ,  0.        ],
#           [ 0.00392157,  0.00392155],
#           [-0.00392157, -0.00392155],
#           ...,
#           [ 0.0039216 ,  0.0039216 ],
#           [ 0.        ,  0.        ],
#           [ 0.        ,  0.        ]],
#
#          [[ 0.        ,  0.        ],
#           [-0.00392155, -0.00392155],
#           [ 0.        ,  0.        ],
#           ...,
#           [ 0.        ,  0.        ],
#           [ 0.00392155,  0.00392155],
#           [ 0.        ,  0.        ]],
#
#          [[ 0.        ,  0.        ],
#           [-0.00392155, -0.00392155],
#           [ 0.        ,  0.        ],
#           ...,
#           [ 0.0039216 ,  0.0039216 ],
#           [ 0.        ,  0.        ],
#           [ 0.        ,  0.        ]]], dtype=float32),
#   array([[[ 0.03137255,  0.        ],
#           [ 0.03921568,  0.        ],
#           [ 0.03725491,  0.        ],
#           ...,
#           [-0.00392157,  0.        ],
#           [-0.02549019,  0.        ],
#           [-0.03137255,  0.        ]],
#
#          [[ 0.01960785,  0.        ],
#           [ 0.02745098,  0.        ],
#           [ 0.02745099,  0.        ],
#           ...,
#           [-0.00392157,  0.        ],
#           [-0.00980392,  0.        ],
#           [-0.02352941,  0.        ]],
#
#          [[ 0.01568628,  0.        ],
#           [ 0.01960784,  0.        ],
#           [ 0.02352941,  0.        ],
#           ...,
#           [ 0.        ,  0.        ],
#           [-0.00196081,  0.        ],
#           [-0.01568624,  0.        ]],
#
#          ...,
#
#          [[-0.03137252,  0.        ],
#           [-0.03137249,  0.        ],
#           [-0.03137249,  0.        ],
#           ...,
#           [-0.03529409,  0.        ],
#           [-0.03529412,  0.        ],
#           [-0.03529409,  0.        ]],
#
#          [[-0.03137255,  0.        ],
#           [-0.03137258,  0.        ],
#           [-0.03137255,  0.        ],
#           ...,
#           [-0.03529412,  0.        ],
#           [-0.03529409,  0.        ],
#           [-0.03529409,  0.        ]],
#
#          [[-0.03137255,  0.        ],
#           [-0.03137258,  0.        ],
#           [-0.03137255,  0.        ],
#           ...,
#           [-0.03529409,  0.        ],
#           [-0.03529412,  0.        ],
#           [-0.03529409,  0.        ]]], dtype=float32),
#   array([[[ 1.8626451e-09,  0.0000000e+00],
#           [ 5.5879354e-09,  0.0000000e+00],
#           [ 1.9607879e-03,  0.0000000e+00],
#           ...,
#           [ 0.0000000e+00,  0.0000000e+00],
#           [ 5.8823489e-03,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00]],
#
#          [[-7.4505806e-09,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00],
#           [ 5.5879354e-09,  0.0000000e+00],
#           ...,
#           [ 3.9215693e-03,  0.0000000e+00],
#           [ 5.8823675e-03,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00]],
#
#          [[-3.9215665e-03,  0.0000000e+00],
#           [ 3.7252903e-09,  0.0000000e+00],
#           [-3.9215693e-03,  0.0000000e+00],
#           ...,
#           [ 0.0000000e+00,  0.0000000e+00],
#           [ 1.9607767e-03,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00]],
#
#          ...,
#
#          [[ 0.0000000e+00,  0.0000000e+00],
#           [ 2.0954758e-08,  0.0000000e+00],
#           [-2.0954758e-08,  0.0000000e+00],
#           ...,
#           [ 0.0000000e+00,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00]],
#
#          [[ 0.0000000e+00,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00],
#           ...,
#           [ 0.0000000e+00,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00]],
#
#          [[ 0.0000000e+00,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00],
#           ...,
#           [ 0.0000000e+00,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00],
#           [ 0.0000000e+00,  0.0000000e+00]]], dtype=float32))]
