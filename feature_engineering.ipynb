# %%
import numpy as np
import pywt  #python wavelet transform
import cv2

# %%
from matplotlib import pyplot as plt
img = cv2.imread('./data/chris_evans/chris_evans1.png')
plt.imshow(img)

# %%
height, width, channels = img.shape
print("Height:", height)
print("Width:", width)
print("Channels:", channels)
# Out:
# Height: 139
# Width: 139
# Channels: 3

# %%
img
# Out:
# array([[[ 25,  28,  36],
#         [ 10,  13,  21],
#         [ 28,  30,  40],
#         ...,
#         [ 93,  90,  85],
#         [122, 120, 112],
#         [113, 111, 103]],
#
#        [[ 13,  19,  24],
#         [ 23,  29,  34],
#         [ 36,  42,  49],
#         ...,
#         [ 65,  63,  62],
#         [109, 108, 104],
#         [116, 116, 110]],
#
#        [[  7,  14,  17],
#         [ 15,  21,  26],
#         [ 26,  32,  37],
#         ...,
#         [ 60,  60,  60],
#         [111, 109, 108],
#         [113, 112, 108]],
#
#        ...,
#
#        [[118, 116, 108],
#         [118, 116, 108],
#         [118, 116, 108],
#         ...,
#         [110, 113, 104],
#         [110, 113, 104],
#         [109, 112, 103]],
#
#        [[119, 117, 109],
#         [119, 117, 109],
#         [119, 117, 109],
#         ...,
#         [110, 113, 104],
#         [109, 112, 103],
#         [109, 112, 103]],
#
#        [[119, 117, 109],
#         [119, 117, 109],
#         [119, 117, 109],
#         ...,
#         [110, 113, 104],
#         [110, 113, 104],
#         [109, 112, 103]]], dtype=uint8)

# %%
img_array = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_array
# Out:
# array([[[ 36,  28,  25],
#         [ 21,  13,  10],
#         [ 40,  30,  28],
#         ...,
#         [ 85,  90,  93],
#         [112, 120, 122],
#         [103, 111, 113]],
#
#        [[ 24,  19,  13],
#         [ 34,  29,  23],
#         [ 49,  42,  36],
#         ...,
#         [ 62,  63,  65],
#         [104, 108, 109],
#         [110, 116, 116]],
#
#        [[ 17,  14,   7],
#         [ 26,  21,  15],
#         [ 37,  32,  26],
#         ...,
#         [ 60,  60,  60],
#         [108, 109, 111],
#         [108, 112, 113]],
#
#        ...,
#
#        [[108, 116, 118],
#         [108, 116, 118],
#         [108, 116, 118],
#         ...,
#         [104, 113, 110],
#         [104, 113, 110],
#         [103, 112, 109]],
#
#        [[109, 117, 119],
#         [109, 117, 119],
#         [109, 117, 119],
#         ...,
#         [104, 113, 110],
#         [103, 112, 109],
#         [103, 112, 109]],
#
#        [[109, 117, 119],
#         [109, 117, 119],
#         [109, 117, 119],
#         ...,
#         [104, 113, 110],
#         [104, 113, 110],
#         [103, 112, 109]]], dtype=uint8)

# %%
plt.imshow(img_array)

# %%
img_array = np.float32(img_array)
img_array
# Out:
# array([[[ 36.,  28.,  25.],
#         [ 21.,  13.,  10.],
#         [ 40.,  30.,  28.],
#         ...,
#         [ 85.,  90.,  93.],
#         [112., 120., 122.],
#         [103., 111., 113.]],
#
#        [[ 24.,  19.,  13.],
#         [ 34.,  29.,  23.],
#         [ 49.,  42.,  36.],
#         ...,
#         [ 62.,  63.,  65.],
#         [104., 108., 109.],
#         [110., 116., 116.]],
#
#        [[ 17.,  14.,   7.],
#         [ 26.,  21.,  15.],
#         [ 37.,  32.,  26.],
#         ...,
#         [ 60.,  60.,  60.],
#         [108., 109., 111.],
#         [108., 112., 113.]],
#
#        ...,
#
#        [[108., 116., 118.],
#         [108., 116., 118.],
#         [108., 116., 118.],
#         ...,
#         [104., 113., 110.],
#         [104., 113., 110.],
#         [103., 112., 109.]],
#
#        [[109., 117., 119.],
#         [109., 117., 119.],
#         [109., 117., 119.],
#         ...,
#         [104., 113., 110.],
#         [103., 112., 109.],
#         [103., 112., 109.]],
#
#        [[109., 117., 119.],
#         [109., 117., 119.],
#         [109., 117., 119.],
#         ...,
#         [104., 113., 110.],
#         [104., 113., 110.],
#         [103., 112., 109.]]], dtype=float32)

# %%
plt.imshow(img_array)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_array/= height
plt.imshow(img_array)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
mode='haar'
level=1
coffs = pywt.wavedec2(img_array, mode, level)
coffs_h = list(coffs)
coffs_h[0] *= 0

# %%
img_array_h = pywt.waverec2(coffs_h, mode)
img_array_h
# Out:
# array([[[ 0.0827338 ,  0.02517986,  0.05395683,  0.05395683],
#         [-0.02517985, -0.0827338 , -0.05395683, -0.05395683],
#         [ 0.07194245,  0.        ,  0.03597122,  0.03597122],
#         ...,
#         [ 0.07374097,  0.13129494,  0.10431655,  0.10431655],
#         [-0.028777  ,  0.028777  ,  0.        ,  0.        ],
#         [-0.028777  ,  0.028777  ,  0.        ,  0.        ]],
#
#        [[-0.01798561, -0.05395684, -0.03597122, -0.03597122],
#         [ 0.05395684,  0.01798561,  0.03597122,  0.03597122],
#         [ 0.10431655,  0.05395681,  0.07913668,  0.07913668],
#         ...,
#         [ 0.1420863 ,  0.17086329,  0.15827338,  0.15827338],
#         [-0.02158272,  0.02158272,  0.        ,  0.        ],
#         [-0.02158272,  0.02158272,  0.        ,  0.        ]],
#
#        [[-0.0179856 , -0.03956835, -0.02877698, -0.02877698],
#         [ 0.04676259,  0.01079136,  0.02877698,  0.02877698],
#         [ 0.0647482 ,  0.02877697,  0.04676259,  0.04676259],
#         ...,
#         [ 0.1708633 ,  0.17805754,  0.18345322,  0.18345322],
#         [-0.01438844,  0.01438844,  0.        ,  0.        ],
#         [-0.01438844,  0.01438844,  0.        ,  0.        ]],
#
#        ...,
#
#        [[-0.02877697,  0.02877697,  0.        ,  0.        ],
#         [-0.02877697,  0.02877697,  0.        ,  0.        ],
#         [-0.02517985,  0.03237411,  0.00359715,  0.00359715],
#         ...,
#         [-0.03237414,  0.03237414,  0.        ,  0.        ],
#         [-0.03237408,  0.03237408,  0.        ,  0.        ],
#         [-0.03237408,  0.03237408,  0.        ,  0.        ]],
#
#        [[-0.028777  ,  0.028777  ,  0.        ,  0.        ],
#         [-0.028777  ,  0.028777  ,  0.        ,  0.        ],
#         [-0.03237412,  0.02517982, -0.00359711, -0.00359711],
#         ...,
#         [-0.03597122,  0.02877696, -0.00359715, -0.00359715],
#         [-0.03237408,  0.03237408,  0.        ,  0.        ],
#         [-0.03237408,  0.03237408,  0.        ,  0.        ]],
#
#        [[-0.028777  ,  0.028777  ,  0.        ,  0.        ],
#         [-0.028777  ,  0.028777  ,  0.        ,  0.        ],
#         [-0.03237412,  0.02517982, -0.00359711, -0.00359711],
#         ...,
#         [-0.03237414,  0.03237414,  0.        ,  0.        ],
#         [-0.03237408,  0.03237408,  0.        ,  0.        ],
#         [-0.03237408,  0.03237408,  0.        ,  0.        ]]],
#       dtype=float32)

# %%
plt.imshow(img_array_h)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_array_h *= 255
img_array_h = np.uint8(img_array_h)
img_array_h
# Out:
# array([[[ 21,   6,  13,  13],
#         [250, 235, 243, 243],
#         [ 18,   0,   9,   9],
#         ...,
#         [ 18,  33,  26,  26],
#         [249,   7,   0,   0],
#         [249,   7,   0,   0]],
#
#        [[252, 243, 247, 247],
#         [ 13,   4,   9,   9],
#         [ 26,  13,  20,  20],
#         ...,
#         [ 36,  43,  40,  40],
#         [251,   5,   0,   0],
#         [251,   5,   0,   0]],
#
#        [[252, 246, 249, 249],
#         [ 11,   2,   7,   7],
#         [ 16,   7,  11,  11],
#         ...,
#         [ 43,  45,  46,  46],
#         [253,   3,   0,   0],
#         [253,   3,   0,   0]],
#
#        ...,
#
#        [[249,   7,   0,   0],
#         [249,   7,   0,   0],
#         [250,   8,   0,   0],
#         ...,
#         [248,   8,   0,   0],
#         [248,   8,   0,   0],
#         [248,   8,   0,   0]],
#
#        [[249,   7,   0,   0],
#         [249,   7,   0,   0],
#         [248,   6,   0,   0],
#         ...,
#         [247,   7,   0,   0],
#         [248,   8,   0,   0],
#         [248,   8,   0,   0]],
#
#        [[249,   7,   0,   0],
#         [249,   7,   0,   0],
#         [248,   6,   0,   0],
#         ...,
#         [248,   8,   0,   0],
#         [248,   8,   0,   0],
#         [248,   8,   0,   0]]], dtype=uint8)

# %%
plt.imshow(img_array_h)

# %%
def w2d(img, mode='haar', level=1):

    img_array = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    img_array = np.float32(img_array)

    height, width, channels = img.shape
    img_array /= height

    coeffs = pywt.wavedec2(img_array, mode, level)
    coeffs_list = list(coeffs)
    coeffs_list[0] *= 0  

    img_array_h = pywt.waverec2(coeffs_list, mode)
    img_array_h *= 255
    img_array_h = np.uint8(img_array_h)

    return img_array_h

# %%
loc = cv2.imread('./data/chris_evans/chris_evans1.png')  
im_har = w2d(loc, 'db1', 5)
plt.imshow(im_har, cmap='gray')

# %%
import os

loc = './data'
dirs = []
avengers = {}

for entry in os.scandir(loc):
    if entry.is_dir():
        dirs.append(entry.path)
        
        for dir in dirs:
            name = dir.split('/')[-1]
            paths = []

            for img_path in os.listdir(dir):
                paths.append(os.path.join(dir, img_path))

            avengers[name] = paths

avengers
# Out:
# {'scarlett_johansson': ['./data/scarlett_johansson/scarlett_johansson43.png',
#   './data/scarlett_johansson/scarlett_johansson18.png',
#   './data/scarlett_johansson/scarlett_johansson38.png',
#   './data/scarlett_johansson/scarlett_johansson22.png',
#   './data/scarlett_johansson/scarlett_johansson7.png',
#   './data/scarlett_johansson/scarlett_johansson16.png',
#   './data/scarlett_johansson/scarlett_johansson46.png',
#   './data/scarlett_johansson/scarlett_johansson45.png',
#   './data/scarlett_johansson/scarlett_johansson47.png',
#   './data/scarlett_johansson/scarlett_johansson34.png',
#   './data/scarlett_johansson/scarlett_johansson35.png',
#   './data/scarlett_johansson/scarlett_johansson28.png',
#   './data/scarlett_johansson/scarlett_johansson50.png',
#   './data/scarlett_johansson/scarlett_johansson51.png',
#   './data/scarlett_johansson/scarlett_johansson17.png',
#   './data/scarlett_johansson/scarlett_johansson29.png',
#   './data/scarlett_johansson/scarlett_johansson1.png',
#   './data/scarlett_johansson/scarlett_johansson54.png',
#   './data/scarlett_johansson/scarlett_johansson21.png',
#   './data/scarlett_johansson/scarlett_johansson42.png',
#   './data/scarlett_johansson/scarlett_johansson52.png',
#   './data/scarlett_johansson/scarlett_johansson36.png',
#   './data/scarlett_johansson/scarlett_johansson30.png',
#   './data/scarlett_johansson/scarlett_johansson40.png',
#   './data/scarlett_johansson/scarlett_johansson23.png',
#   './data/scarlett_johansson/scarlett_johansson5.png',
#   './data/scarlett_johansson/scarlett_johansson15.png',
#   './data/scarlett_johansson/scarlett_johansson3.png',
#   './data/scarlett_johansson/scarlett_johansson4.png',
#   './data/scarlett_johansson/scarlett_johansson20.png',
#   './data/scarlett_johansson/scarlett_johansson19.png',
#   './data/scarlett_johansson/scarlett_johansson10.png',
#   './data/scarlett_johansson/scarlett_johansson48.png',
#   './data/scarlett_johansson/scarlett_johansson27.png',
#   './data/scarlett_johansson/scarlett_johansson37.png',
#   './data/scarlett_johansson/scarlett_johansson26.png',
#   './data/scarlett_johansson/scarlett_johansson24.png',
#   './data/scarlett_johansson/scarlett_johansson31.png',
#   './data/scarlett_johansson/scarlett_johansson9.png',
#   './data/scarlett_johansson/scarlett_johansson12.png',
#   './data/scarlett_johansson/scarlett_johansson11.png',
#   './data/scarlett_johansson/scarlett_johansson14.png',
#   './data/scarlett_johansson/scarlett_johansson49.png',
#   './data/scarlett_johansson/scarlett_johansson6.png',
#   './data/scarlett_johansson/scarlett_johansson13.png',
#   './data/scarlett_johansson/scarlett_johansson8.png',
#   './data/scarlett_johansson/scarlett_johansson39.png',
#   './data/scarlett_johansson/scarlett_johansson2.png',
#   './data/scarlett_johansson/scarlett_johansson44.png',
#   './data/scarlett_johansson/scarlett_johansson32.png',
#   './data/scarlett_johansson/scarlett_johansson53.png',
#   './data/scarlett_johansson/scarlett_johansson41.png',
#   './data/scarlett_johansson/scarlett_johansson25.png',
#   './data/scarlett_johansson/scarlett_johansson33.png'],
#  'mark_ruffalo': ['./data/mark_ruffalo/mark_ruffalo2.png',
#   './data/mark_ruffalo/mark_ruffalo50.png',
#   './data/mark_ruffalo/mark_ruffalo48.png',
#   './data/mark_ruffalo/mark_ruffalo34.png',
#   './data/mark_ruffalo/mark_ruffalo24.png',
#   './data/mark_ruffalo/mark_ruffalo31.png',
#   './data/mark_ruffalo/mark_ruffalo66.png',
#   './data/mark_ruffalo/mark_ruffalo40.png',
#   './data/mark_ruffalo/mark_ruffalo43.png',
#   './data/mark_ruffalo/mark_ruffalo65.png',
#   './data/mark_ruffalo/mark_ruffalo45.png',
#   './data/mark_ruffalo/mark_ruffalo51.png',
#   './data/mark_ruffalo/mark_ruffalo56.png',
#   './data/mark_ruffalo/mark_ruffalo62.png',
#   './data/mark_ruffalo/mark_ruffalo55.png',
#   './data/mark_ruffalo/mark_ruffalo1.png',
#   './data/mark_ruffalo/mark_ruffalo15.png',
#   './data/mark_ruffalo/mark_ruffalo23.png',
#   './data/mark_ruffalo/mark_ruffalo36.png',
#   './data/mark_ruffalo/mark_ruffalo17.png',
#   './data/mark_ruffalo/mark_ruffalo14.png',
#   './data/mark_ruffalo/mark_ruffalo26.png',
#   './data/mark_ruffalo/mark_ruffalo18.png',
#   './data/mark_ruffalo/mark_ruffalo28.png',
#   './data/mark_ruffalo/mark_ruffalo57.png',
#   './data/mark_ruffalo/mark_ruffalo59.png',
#   './data/mark_ruffalo/mark_ruffalo8.png',
#   './data/mark_ruffalo/mark_ruffalo20.png',
#   './data/mark_ruffalo/mark_ruffalo53.png',
#   './data/mark_ruffalo/mark_ruffalo12.png',
#   './data/mark_ruffalo/mark_ruffalo41.png',
#   './data/mark_ruffalo/mark_ruffalo35.png',
#   './data/mark_ruffalo/mark_ruffalo4.png',
#   './data/mark_ruffalo/mark_ruffalo63.png',
#   './data/mark_ruffalo/mark_ruffalo11.png',
#   './data/mark_ruffalo/mark_ruffalo16.png',
#   './data/mark_ruffalo/mark_ruffalo32.png',
#   './data/mark_ruffalo/mark_ruffalo21.png',
#   './data/mark_ruffalo/mark_ruffalo19.png',
#   './data/mark_ruffalo/mark_ruffalo39.png',
#   './data/mark_ruffalo/mark_ruffalo52.png',
#   './data/mark_ruffalo/mark_ruffalo61.png',
#   './data/mark_ruffalo/mark_ruffalo27.png',
#   './data/mark_ruffalo/mark_ruffalo13.png',
#   './data/mark_ruffalo/mark_ruffalo37.png',
#   './data/mark_ruffalo/mark_ruffalo54.png',
#   './data/mark_ruffalo/mark_ruffalo10.png',
#   './data/mark_ruffalo/mark_ruffalo30.png',
#   './data/mark_ruffalo/mark_ruffalo60.png',
#   './data/mark_ruffalo/mark_ruffalo64.png',
#   './data/mark_ruffalo/mark_ruffalo9.png',
#   './data/mark_ruffalo/mark_ruffalo42.png',
#   './data/mark_ruffalo/mark_ruffalo33.png',
#   './data/mark_ruffalo/mark_ruffalo7.png',
#   './data/mark_ruffalo/mark_ruffalo58.png',
#   './data/mark_ruffalo/mark_ruffalo49.png',
#   './data/mark_ruffalo/mark_ruffalo3.png',
#   './data/mark_ruffalo/mark_ruffalo25.png',
#   './data/mark_ruffalo/mark_ruffalo38.png',
#   './data/mark_ruffalo/mark_ruffalo5.png',
#   './data/mark_ruffalo/mark_ruffalo47.png',
#   './data/mark_ruffalo/mark_ruffalo6.png',
#   './data/mark_ruffalo/mark_ruffalo22.png',
#   './data/mark_ruffalo/mark_ruffalo46.png',
#   './data/mark_ruffalo/mark_ruffalo29.png',
#   './data/mark_ruffalo/mark_ruffalo44.png'],
#  'robert_downey_jr': ['./data/robert_downey_jr/robert_downey_jr23.png',
#   './data/robert_downey_jr/robert_downey_jr51.png',
#   './data/robert_downey_jr/robert_downey_jr38.png',
#   './data/robert_downey_jr/robert_downey_jr41.png',
#   './data/robert_downey_jr/robert_downey_jr24.png',
#   './data/robert_downey_jr/robert_downey_jr36.png',
#   './data/robert_downey_jr/robert_downey_jr34.png',
#   './data/robert_downey_jr/robert_downey_jr5.png',
#   './data/robert_downey_jr/robert_downey_jr44.png',
#   './data/robert_downey_jr/robert_downey_jr35.png',
#   './data/robert_downey_jr/robert_downey_jr7.png',
#   './data/robert_downey_jr/robert_downey_jr15.png',
#   './data/robert_downey_jr/robert_downey_jr43.png',
#   './data/robert_downey_jr/robert_downey_jr33.png',
#   './data/robert_downey_jr/robert_downey_jr42.png',
#   './data/robert_downey_jr/robert_downey_jr39.png',
#   './data/robert_downey_jr/robert_downey_jr31.png',
#   './data/robert_downey_jr/robert_downey_jr45.png',
#   './data/robert_downey_jr/robert_downey_jr11.png',
#   './data/robert_downey_jr/robert_downey_jr40.png',
#   './data/robert_downey_jr/robert_downey_jr10.png',
#   './data/robert_downey_jr/robert_downey_jr9.png',
#   './data/robert_downey_jr/robert_downey_jr47.png',
#   './data/robert_downey_jr/robert_downey_jr46.png',
#   './data/robert_downey_jr/robert_downey_jr29.png',
#   './data/robert_downey_jr/robert_downey_jr8.png',
#   './data/robert_downey_jr/robert_downey_jr13.png',
#   './data/robert_downey_jr/robert_downey_jr32.png',
#   './data/robert_downey_jr/robert_downey_jr50.png',
#   './data/robert_downey_jr/robert_downey_jr26.png',
#   './data/robert_downey_jr/robert_downey_jr25.png',
#   './data/robert_downey_jr/robert_downey_jr28.png',
#   './data/robert_downey_jr/robert_downey_jr4.png',
#   './data/robert_downey_jr/robert_downey_jr37.png',
#   './data/robert_downey_jr/robert_downey_jr18.png',
#   './data/robert_downey_jr/robert_downey_jr19.png',
#   './data/robert_downey_jr/robert_downey_jr12.png',
#   './data/robert_downey_jr/robert_downey_jr20.png',
#   './data/robert_downey_jr/robert_downey_jr1.png',
#   './data/robert_downey_jr/robert_downey_jr6.png',
#   './data/robert_downey_jr/robert_downey_jr27.png',
#   './data/robert_downey_jr/robert_downey_jr30.png',
#   './data/robert_downey_jr/robert_downey_jr3.png',
#   './data/robert_downey_jr/robert_downey_jr17.png',
#   './data/robert_downey_jr/robert_downey_jr22.png',
#   './data/robert_downey_jr/robert_downey_jr2.png',
#   './data/robert_downey_jr/robert_downey_jr48.png',
#   './data/robert_downey_jr/robert_downey_jr49.png',
#   './data/robert_downey_jr/robert_downey_jr14.png',
#   './data/robert_downey_jr/robert_downey_jr21.png',
#   './data/robert_downey_jr/robert_downey_jr16.png'],
#  'chris_evans': ['./data/chris_evans/chris_evans39.png',
#   './data/chris_evans/chris_evans6.png',
#   './data/chris_evans/chris_evans12.png',
#   './data/chris_evans/chris_evans15.png',
#   './data/chris_evans/chris_evans3.png',
#   './data/chris_evans/chris_evans24.png',
#   './data/chris_evans/chris_evans41.png',
#   './data/chris_evans/chris_evans50.png',
#   './data/chris_evans/chris_evans49.png',
#   './data/chris_evans/chris_evans32.png',
#   './data/chris_evans/chris_evans23.png',
#   './data/chris_evans/chris_evans25.png',
#   './data/chris_evans/chris_evans1.png',
#   './data/chris_evans/chris_evans45.png',
#   './data/chris_evans/chris_evans48.png',
#   './data/chris_evans/chris_evans8.png',
#   './data/chris_evans/chris_evans42.png',
#   './data/chris_evans/chris_evans43.png',
#   './data/chris_evans/chris_evans5.png',
#   './data/chris_evans/chris_evans22.png',
#   './data/chris_evans/chris_evans36.png',
#   './data/chris_evans/chris_evans10.png',
#   './data/chris_evans/chris_evans28.png',
#   './data/chris_evans/chris_evans11.png',
#   './data/chris_evans/chris_evans35.png',
#   './data/chris_evans/chris_evans26.png',
#   './data/chris_evans/chris_evans46.png',
#   './data/chris_evans/chris_evans34.png',
#   './data/chris_evans/chris_evans20.png',
#   './data/chris_evans/chris_evans47.png',
#   './data/chris_evans/chris_evans13.png',
#   './data/chris_evans/chris_evans38.png',
#   './data/chris_evans/chris_evans27.png',
#   './data/chris_evans/chris_evans44.png',
#   './data/chris_evans/chris_evans30.png',
#   './data/chris_evans/chris_evans37.png',
#   './data/chris_evans/chris_evans21.png',
#   './data/chris_evans/chris_evans18.png',
#   './data/chris_evans/chris_evans29.png',
#   './data/chris_evans/chris_evans14.png',
#   './data/chris_evans/chris_evans17.png',
#   './data/chris_evans/chris_evans2.png',
#   './data/chris_evans/chris_evans31.png',
#   './data/chris_evans/chris_evans9.png',
#   './data/chris_evans/chris_evans16.png',
#   './data/chris_evans/chris_evans4.png',
#   './data/chris_evans/chris_evans33.png',
#   './data/chris_evans/chris_evans19.png',
#   './data/chris_evans/chris_evans7.png',
#   './data/chris_evans/chris_evans40.png'],
#  'chris_hemsworth': ['./data/chris_hemsworth/chris_hemsworth7.png',
#   './data/chris_hemsworth/chris_hemsworth46.png',
#   './data/chris_hemsworth/chris_hemsworth1.png',
#   './data/chris_hemsworth/chris_hemsworth31.png',
#   './data/chris_hemsworth/chris_hemsworth41.png',
#   './data/chris_hemsworth/chris_hemsworth4.png',
#   './data/chris_hemsworth/chris_hemsworth18.png',
#   './data/chris_hemsworth/chris_hemsworth6.png',
#   './data/chris_hemsworth/chris_hemsworth15.png',
#   './data/chris_hemsworth/chris_hemsworth29.png',
#   './data/chris_hemsworth/chris_hemsworth37.png',
#   './data/chris_hemsworth/chris_hemsworth9.png',
#   './data/chris_hemsworth/chris_hemsworth49.png',
#   './data/chris_hemsworth/chris_hemsworth11.png',
#   './data/chris_hemsworth/chris_hemsworth23.png',
#   './data/chris_hemsworth/chris_hemsworth34.png',
#   './data/chris_hemsworth/chris_hemsworth28.png',
#   './data/chris_hemsworth/chris_hemsworth19.png',
#   './data/chris_hemsworth/chris_hemsworth13.png',
#   './data/chris_hemsworth/chris_hemsworth20.png',
#   './data/chris_hemsworth/chris_hemsworth35.png',
#   './data/chris_hemsworth/chris_hemsworth33.png',
#   './data/chris_hemsworth/chris_hemsworth10.png',
#   './data/chris_hemsworth/chris_hemsworth36.png',
#   './data/chris_hemsworth/chris_hemsworth39.png',
#   './data/chris_hemsworth/chris_hemsworth12.png',
#   './data/chris_hemsworth/chris_hemsworth22.png',
#   './data/chris_hemsworth/chris_hemsworth51.png',
#   './data/chris_hemsworth/chris_hemsworth25.png',
#   './data/chris_hemsworth/chris_hemsworth50.png',
#   './data/chris_hemsworth/chris_hemsworth8.png',
#   './data/chris_hemsworth/chris_hemsworth43.png',
#   './data/chris_hemsworth/chris_hemsworth38.png',
#   './data/chris_hemsworth/chris_hemsworth27.png',
#   './data/chris_hemsworth/chris_hemsworth42.png',
#   './data/chris_hemsworth/chris_hemsworth14.png',
#   './data/chris_hemsworth/chris_hemsworth17.png',
#   './data/chris_hemsworth/chris_hemsworth52.png',
#   './data/chris_hemsworth/chris_hemsworth2.png',
#   './data/chris_hemsworth/chris_hemsworth30.png',
#   './data/chris_hemsworth/chris_hemsworth53.png',
#   './data/chris_hemsworth/chris_hemsworth16.png',
#   './data/chris_hemsworth/chris_hemsworth45.png',
#   './data/chris_hemsworth/chris_hemsworth26.png',
#   './data/chris_hemsworth/chris_hemsworth47.png',
#   './data/chris_hemsworth/chris_hemsworth40.png',
#   './data/chris_hemsworth/chris_hemsworth24.png',
#   './data/chris_hemsworth/chris_hemsworth48.png',
#   './data/chris_hemsworth/chris_hemsworth21.png',
#   './data/chris_hemsworth/chris_hemsworth44.png',
#   './data/chris_hemsworth/chris_hemsworth5.png',
#   './data/chris_hemsworth/chris_hemsworth32.png',
#   './data/chris_hemsworth/chris_hemsworth3.png']}

# %%
#Labeling
class_dict = {}
count = 0

for celebrity_name in avengers.keys():
    class_dict[celebrity_name] = count
    count = count + 1

class_dict
# Out:
# {'scarlett_johansson': 0,
#  'mark_ruffalo': 1,
#  'robert_downey_jr': 2,
#  'chris_evans': 3,
#  'chris_hemsworth': 4}

# %%
x, y = [], []

for key, paths in avengers.items():
    for path in paths:
        normal_img = cv2.imread(path)
        normal_scal = cv2.resize(normal_img, (32, 32))  # Corrected
        discret_img = w2d(normal_img, 'db1', 5)  # Corrected
        discret_img = cv2.cvtColor(discret_img, cv2.COLOR_RGBA2RGB) if discret_img.shape[2] == 4 else discret_img[:, :, :3]  # Convert to RGB if RGBA, else keep only first 3 channels
        discret_scal = cv2.resize(discret_img, (32, 32))

        combined_img = np.vstack((normal_scal.reshape(32*32*3, 1), discret_scal.reshape(32*32*3, 1)))  # Corrected
        x.append(combined_img)
        y.append(class_dict[key])

# %%
len(x[0])
# Out:
# 6144

# %%
x = np.array(x).reshape(len(x),6144).astype(float)
x.shape
# Out:
# (274, 6144)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, random_state=0)

pipe = Pipeline([('scalar', StandardScaler()), ('svm', SVC(kernel = 'rbf', C=18))])
pipe.fit(xtrain, ytrain)
pipe.score(xtest, ytest)
# Out:
# 0.6231884057971014

# %%
print(classification_report(ytest,pipe.predict(xtest)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        11
#            1       0.67      0.56      0.61        18
#            2       0.41      0.70      0.52        10
#            3       0.67      0.47      0.55        17
#            4       0.58      0.54      0.56        13
#
#     accuracy                           0.62        69
#    macro avg       0.63      0.65      0.63        69
# weighted avg       0.64      0.62      0.62        69

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}

import pandas as pd

for algo, mp in model_params.items():

    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(xtrain, ytrain)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.765854
# 1        random_forest    0.502439
# 2  logistic_regression    0.780488
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators['logistic_regression'].score(xtest, ytest)
# Out:
# 0.6811594202898551

# %%
model = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest, model.predict(xtest))
cm
# Out:
# array([[11,  0,  0,  0,  0],
#        [ 0, 11,  3,  2,  2],
#        [ 1,  1,  6,  1,  1],
#        [ 1,  1,  0, 11,  4],
#        [ 1,  1,  1,  2,  8]])

# %%
class_dict
# Out:
# {'scarlett_johansson': 0,
#  'mark_ruffalo': 1,
#  'robert_downey_jr': 2,
#  'chris_evans': 3,
#  'chris_hemsworth': 4}

# %%
import seaborn as sn
plt.figure(figsize=(7,5))
sn.heatmap(cm,annot=True)
plt.xlabel("predict")
plt.ylabel("Truth")
# Out:
# Text(58.222222222222214, 0.5, 'Truth')

# %%
import joblib

joblib.dump(mode,'model.pkl')
# Out:
# ['model.pkl']

# %%
import json
with open("dict.json","w") as f:
    json.dump(class_dict,f)
